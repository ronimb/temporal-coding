# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set()
import numpy as np

# %% [markdown]
# Specify data location and load the data

# %%
data_location = '/home/ron/OneDrive/Documents/Masters/Parnas/temporal-coding/Results/exp_results.pickle'
data = pd.read_pickle(data_location)
data.head()
# Out:
#    duration  frequency  number_of_neurons  model_threshold  learning_rate  \
# 0       500         15                 30            0.025        0.00005
# 1       500         15                 30            0.025        0.00005
# 2       500         15                 30            0.025        0.00005
# 3       500         15                 30            0.025        0.00005
# 4       500         15                 30            0.025        0.00005
#
#    orig_a_mean_freq  orig_b_mean_freq orig_difference  orig_distance  \
# 0         15.666667         15.666667          (3, 5)       0.000054
# 1         15.866667         15.866667          (3, 5)       0.000068
# 2         16.533333         16.533333          (3, 5)       0.000073
# 3         14.333333         14.333333          (3, 5)       0.000036
# 4         13.733333         13.733333          (3, 5)       0.000033
#
#    set_size  release_duration  number_of_vesicles  release_probability  \
# ...

# %%
data.groupby('frequency', 'set_size').mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-fb300b4f6e6d> in <module>
# ----> 1 data.groupby('frequency', 'set_size').mean()
#
# ~/.conda/envs/temporal_coding/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6660         if level is None and by is None:
#    6661             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 6662         axis = self._get_axis_number(axis)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# ~/.conda/envs/temporal_coding/lib/python3.6/site-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     373                 pass
# ...
